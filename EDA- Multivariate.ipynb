# %%
# Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# For avoiding the truncating of rows and column

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns', None)

# %%
# Import dataset

df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
# Top 5 rows

df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat        bestech altura  sector 79   1.85          8604.0
# 1          flat            rof ananda  sector 95   0.46          6318.0
# 2         house           independent   sector 9   0.22          7407.0
# 3          flat  umang monsoon breeze  sector 78   0.95          5491.0
# 4          flat         tata primanti  sector 72   4.00         13769.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0  2150.0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1   728.0          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2   297.0           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3  1730.0      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  2905.0  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0      11.0       North    New Property               2150.0            NaN
# 1      11.0  North-West    New Property                  NaN            NaN
# 2       1.0         NaN       Undefined                  NaN            NaN
# 3       9.0        East  Relatively New                  NaN         1730.0
# 4       7.0  South-East  Moderately Old               2905.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0          NaN           0             1           0           0       0
# 1        728.0           1             0           0           0       0
# 2         33.0           0             0           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             1           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            49
# 1                1            82
# 2                1             0
# 3                2            65
# 4                1            38

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier

df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers


df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 195          house            vatika india next  sector 82   7.00
# 207          house                        ansal  sector 43   1.85
# 517          house       dlf city plots phase 2  sector 25  10.00
# 774          house                  independent  sector 23   2.80
# 834          house               uppal southend  sector 49   6.75
# 841          house         bhim nagar, sector 6   sector 6   0.85
# 927          house         eros rosewood villas  sector 49   2.75
# 1104         house                  independent  sector 55   1.45
# 1274         house                  independent  sector 54   3.75
# 1512         house                  independent   sector 4   0.60
# 1559         house                  independent  sector 38   8.00
# 1633         house                    rk excelo  sector 12   0.60
# 1680         house       unitech deerwood chase  sector 50   8.45
# 1853         house                  independent  sector 24  10.00
# 1873          flat           ambience caitriona  sector 24  14.00
# 2185         house                  independent  sector 57   8.00
# 2280         house                  independent  sector 12   6.00
# 2320         house                  independent  sector 17   3.50
# 2467         house                   ardee city  sector 52   5.50
# 2541         house     unitech uniworld resorts  sector 33  10.00
# 2572         house                  independent  sector 12   3.50
# 2592         house          huda plot sector 38  sector 38   4.30
# 2749         house                  independent  sector 28   4.50
# 2804         house  unitech nirvana birch court  sector 50   7.10
# 2900         house       emaar the palm springs  sector 54  24.00
# 2911         house           vipul tatvam villa  sector 48   7.25
# 3527         house                dlf the grove  sector 54   5.70
# 3559         house     unitech uniworld resorts  sector 33   9.50
# 3769         house       dlf city plots phase 2  sector 25  10.50
#
#       price_per_sqft   area  \
# 195         194444.0  360.0
# 207         308333.0   60.0
# 517         400000.0  250.0
# 774         161849.0  173.0
# 834         290948.0  232.0
# 841         126865.0   67.0
# 927         178571.0  154.0
# 1104        241666.0   60.0
# 1274        234375.0  160.0
# 1512        105263.0   57.0
# 1559        230547.0  347.0
# 1633        120000.0   50.0
# 1680        235376.0  359.0
# 1853        229885.0  435.0
# 1873        200000.0  700.0
# 2185        266666.0  300.0
# 2280        315789.0  190.0
# 2320        218750.0  160.0
# 2467        183333.0  300.0
# 2541        181818.0  550.0
# 2572        133079.0  263.0
# 2592        245398.0  175.0
# 2749        125000.0  360.0
# 2804        283333.0  251.0
# 2900        600000.0  400.0
# 2911        201388.0  360.0
# 3527        211111.0  270.0
# 3559        173992.0  546.0
# 3769        261194.0  402.0
#
#                                            areaWithType  super_built_up_area  \
# 195   Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 207                            Plot area 60(5.57 sq.m.)                  NaN
# 517                          Plot area 250(23.23 sq.m.)                  NaN
# 774   Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 834                          Plot area 232(21.55 sq.m.)                  NaN
# 841                            Plot area 67(6.22 sq.m.)                  NaN
# 927   Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 1104                           Plot area 60(5.57 sq.m.)                  NaN
# 1274                         Plot area 160(14.86 sq.m.)                  NaN
# 1512                            Plot area 57(5.3 sq.m.)                  NaN
# 1559  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 1633  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1680                         Plot area 359(33.35 sq.m.)                  NaN
# 1853                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1873                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 2185                         Plot area 300(27.87 sq.m.)                  NaN
# 2280  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2320                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 2467                         Plot area 300(27.87 sq.m.)                  NaN
# 2541                          Plot area 550(51.1 sq.m.)                  NaN
# 2572  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2592  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 2749                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2804                          Plot area 240(22.3 sq.m.)                  NaN
# 2900                         Plot area 400(37.16 sq.m.)                  NaN
# 2911                         Plot area 360(33.45 sq.m.)                  NaN
# 3527                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3559                         Plot area 546(50.73 sq.m.)                  NaN
# 3769                         Plot area 402(37.35 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 195          3900.0       3743.0
# 207            60.0          NaN
# 517           250.0          NaN
# 774           160.0        150.0
# 834           232.0          NaN
# 841            67.0          NaN
# 927             NaN       1650.0
# 1104           60.0          NaN
# 1274          160.0          NaN
# 1512           57.0          NaN
# 1559          347.0        215.0
# 1633           30.0         15.0
# 1680          359.0          NaN
# 1853            NaN        435.0
# 1873          700.0          NaN
# 2185          300.0          NaN
# 2280            NaN       1600.0
# 2320          160.0          NaN
# 2467          300.0          NaN
# 2541          550.0          NaN
# 2572         4800.0       4400.0
# 2592          145.0          NaN
# 2749          360.0          NaN
# 2804          240.0          NaN
# 2900          400.0          NaN
# 2911          360.0          NaN
# 3527          270.0          NaN
# 3559          546.0          NaN
# 3769          402.0          NaN

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat        bestech altura  sector 79   1.85          8604.0
# 1          flat            rof ananda  sector 95   0.46          6318.0
# 2         house           independent   sector 9   0.22          7407.0
# 3          flat  umang monsoon breeze  sector 78   0.95          5491.0
# 4          flat         tata primanti  sector 72   4.00         13769.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0  2150.0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1   728.0          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2   297.0           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3  1730.0      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  2905.0  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0      11.0       North    New Property               2150.0            NaN
# 1      11.0  North-West    New Property                  NaN            NaN
# 2       1.0         NaN       Undefined                  NaN            NaN
# 3       9.0        East  Relatively New                  NaN         1730.0
# 4       7.0  South-East  Moderately Old               2905.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0          NaN           0             1           0           0       0
# 1        728.0           1             0           0           0       0
# 2         33.0           0             0           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             1           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            49
# 1                1            82
# 2                1             0
# 3                2            65
# 4                1            38

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers

df[df['bedRoom'] >= 10]
# Out:
#      property_type                      society           sector  price  \
# 85           house                  independent        sector 54   5.50
# 109          house                  independent       sector 104   0.80
# 135          house                  independent        sector 43   2.10
# 138          house                  independent        sector 26  10.50
# 146          house                  independent        sector 43   3.00
# 237          house                     shivpuri         sector 7   2.40
# 262          house                  independent        sector 25   9.00
# 275          house                  independent        sector 46   6.81
# 460          house                  independent        sector 24   4.50
# 467          house                  independent        sector 39   7.00
# 517          house       dlf city plots phase 2        sector 25  10.00
# 519          house                  independent        sector 40   9.50
# 532          house                  independent        sector 55   7.49
# 600          house                  independent        sector 28    NaN
# 612          house                  independent        sector 26  26.00
# 730          house                  independent        sector 28  11.00
# 739          house                  independent        sector 43   7.50
# 803          house                     shivpuri         sector 7   2.80
# 830          house                  independent        sector 43   2.20
# 834          house               uppal southend        sector 49   6.75
# 844          house                  independent        sector 13   9.00
# 913          house                  independent        sector 25    NaN
# 1017         house       dlf city plots phase 3        sector 24   5.00
# 1056         house                  independent        sector 46   6.50
# 1090         house                  independent        sector 31   9.25
# 1136         house                 malibu towne        sector 47   8.50
# 1194         house                  independent        sector 25  16.00
# 1227         house                private house        sector 55   7.05
# 1256         house    floor wise designer kothi        sector 25  13.00
# 1273         house                  independent  sohna road road   0.95
# 1428         house                  independent        sector 56  11.50
# 1559         house                  independent        sector 38   8.00
# 1567         house                  independent        sector 24   3.20
# 1609         house                  independent        sector 56  12.39
# 1721         house                  independent        sector 43   2.25
# 1733         house                  independent        sector 56   8.00
# 1754         house                  independent        sector 55   9.19
# 1845         house                  independent        sector 13   2.25
# 1861         house                  independent        sector 57   6.95
# 2055         house               uppal southend        sector 49   6.75
# 2272         house                  independent        sector 11   3.50
# 2303         house                  independent       sector 17a   3.87
# 2316         house                  independent        sector 11   1.35
# 2329         house    ganpati heights apartment        sector 13   1.25
# 2335         house       laxmi garden sector-11        sector 11   1.50
# 2340         house                  independent         sector 9   1.25
# 2452         house   unitech palms south city 1        sector 41   9.35
# 2476         house       luxury dlf city floors        sector 26   8.25
# 2523         house               uppal southend        sector 49   6.75
# 2582         house          dlf pink town house        sector 24   1.90
# 2592         house          huda plot sector 38        sector 38   4.30
# 2600         house                  independent        sector 13   0.50
# 2682         house               dlf city plots        sector 26  20.00
# 2727         house                  independent        sector 43   4.50
# 2761         house                  independent        sector 40  12.00
# 2814         house                  independent        sector 26  14.75
# 2960         house             dlf city phase 1        sector 26   9.25
# 2971         house                  independent       sector 17a   3.93
# 3075         house        dlf city plot phase 4        sector 28  13.00
# 3165         house                  independent        sector 26   8.49
# 3218         house                  independent        sector 11   4.50
# 3274         house                  independent        sector 54   5.00
# 3278         house                  independent        sector 56  11.95
# 3288         house                  independent        sector 47   6.09
# 3377         house                  independent        sector 27   8.25
# 3465         house                  independent        sector 13   1.50
# 3478         house                  independent        sector 43  13.50
# 3495         house                          nul        sector 28  12.50
# 3585         house                  independent        sector 14   8.00
# 3669         house  independent house sector 45        sector 40   9.00
# 3726         house       luxury dlf city floors        sector 26  20.00
# 3793         house                  independent        sector 41   4.25
#
#       price_per_sqft     area  \
# 85           38194.0   1440.0
# 109          80000.0    100.0
# 135          38251.0    549.0
# 138          43210.0   2430.0
# 146          53763.0    558.0
# 237           8889.0   2700.0
# 262          28490.0   3159.0
# 275          36911.0   1845.0
# 460          33333.0   1350.0
# 467          10000.0   7000.0
# 517         400000.0    250.0
# 519          40135.0   2367.0
# 532          27741.0   2700.0
# 600              NaN      NaN
# 612          82540.0   3150.0
# 730          33951.0   3240.0
# 739          38760.0   1935.0
# 803          12444.0   2250.0
# 830           6875.0   3200.0
# 834         290948.0    232.0
# 844         100000.0    900.0
# 913              NaN      NaN
# 1017         34083.0   1467.0
# 1056         27461.0   2367.0
# 1090         39530.0   2340.0
# 1136         53125.0   1600.0
# 1194         59259.0   2700.0
# 1227         46906.0   1503.0
# 1256         48148.0   2700.0
# 1273          8920.0   1065.0
# 1428         42032.0   2736.0
# 1559        230547.0    347.0
# 1567         59259.0    540.0
# 1609         45889.0   2700.0
# 1721          7500.0   3000.0
# 1733          9654.0   8287.0
# 1754         34037.0   2700.0
# 1845          6944.0   3240.0
# 1861         38611.0   1800.0
# 2055         32328.0   2088.0
# 2272         15555.0   2250.0
# 2303          5160.0   7500.0
# 2316          3857.0   3500.0
# 2329           151.0  82781.0
# 2335         12820.0   1170.0
# 2340          8735.0   1431.0
# 2452         28858.0   3240.0
# 2476         45833.0   1800.0
# 2523         31915.0   2115.0
# 2582          3786.0   5018.0
# 2592        245398.0    175.0
# 2600         90909.0     55.0
# 2682         44265.0   4518.0
# 2727         39062.0   1152.0
# 2761         38986.0   3078.0
# 2814         51864.0   2844.0
# 2960         47803.0   1935.0
# 2971         24214.0   1623.0
# 3075          1992.0  65261.0
# 3165         47167.0   1800.0
# 3218         25000.0   1800.0
# 3274         43066.0   1161.0
# 3278         43534.0   2745.0
# 3288         33665.0   1809.0
# 3377         45833.0   1800.0
# 3465         11538.0   1300.0
# 3478         50000.0   2700.0
# 3495         51440.0   2430.0
# 3585         17707.0   4518.0
# 3669         38022.0   2367.0
# 3726         48889.0   4091.0
# 3793         26235.0   1620.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 85                          Plot area 160(133.78 sq.m.)       18        18
# 109                           Plot area 100(9.29 sq.m.)       13         6
# 135                              Plot area 61(51 sq.m.)       10        10
# 138   Plot area 302(252.51 sq.m.)Built Up area: 300 ...       12        12
# 146                           Plot area 62(51.84 sq.m.)       12        12
# 237                         Plot area 300(250.84 sq.m.)       10         5
# 262                         Plot area 351(293.48 sq.m.)       10        10
# 275                         Plot area 205(171.41 sq.m.)       12        14
# 460   Plot area 163(136.29 sq.m.)Built Up area: 160 ...       10         8
# 467   Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10        11
# 517                          Plot area 250(23.23 sq.m.)       12        12
# 519                          Plot area 263(219.9 sq.m.)       12        12
# 532                         Plot area 300(250.84 sq.m.)       12        12
# 600                         Plot area 270(225.75 sq.m.)       16        16
# 612   Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 730                         Plot area 360(301.01 sq.m.)       13        13
# 739                         Plot area 215(179.77 sq.m.)       12        12
# 803                        Plot area 2250(209.03 sq.m.)       10         7
# 830                        Plot area 3200(297.29 sq.m.)       12        12
# 834                          Plot area 232(21.55 sq.m.)       12        12
# 844                          Plot area 900(83.61 sq.m.)       10         5
# 913   Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# 1017                        Plot area 163(136.29 sq.m.)       13        13
# 1056                         Plot area 263(219.9 sq.m.)       12        12
# 1090  Plot area 265(221.57 sq.m.)Built Up area: 262 ...       12        12
# 1136                 Built Up area: 1600 (148.64 sq.m.)       12        12
# 1194  Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 1227                        Plot area 167(139.63 sq.m.)       18        18
# 1256                        Plot area 300(250.84 sq.m.)       12        16
# 1273                        Plot area 1065(98.94 sq.m.)       10        10
# 1428                        Plot area 304(254.18 sq.m.)       12        13
# 1559  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 1567                          Plot area 60(50.17 sq.m.)       14        14
# 1609                        Plot area 300(250.84 sq.m.)       16        18
# 1721  Plot area 550(51.1 sq.m.)Built Up area: 3000 s...       11        11
# 1733  Plot area 362(33.63 sq.m.)Built Up area: 8286 ...       10        10
# 1754                        Plot area 300(250.84 sq.m.)       16        18
# 1845                    Carpet area: 360 (301.01 sq.m.)       10        10
# 1861                        Plot area 192(160.54 sq.m.)       12        12
# 2055                        Plot area 232(193.98 sq.m.)       12        12
# 2272                 Built Up area: 2250 (209.03 sq.m.)       10         1
# 2303  Plot area 1623(150.78 sq.m.)Built Up area: 750...       19        17
# 2316                       Plot area 3500(325.16 sq.m.)       10         6
# 2329                       Plot area 115(7692.86 sq.m.)       10         6
# 2335                         Plot area 130(108.7 sq.m.)       12         9
# 2340                        Plot area 159(132.94 sq.m.)       10         6
# 2452  Plot area 3240(301.01 sq.m.)Built Up area: 750...       10        10
# 2476                        Plot area 200(167.23 sq.m.)       12        12
# 2523                        Plot area 235(196.49 sq.m.)       12        12
# 2582                 Built Up area: 5018 (466.19 sq.m.)       10         9
# 2592  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 2600                           Plot area 55(5.11 sq.m.)       12         4
# 2682                        Plot area 502(419.74 sq.m.)       16        20
# 2727                        Plot area 128(107.02 sq.m.)       20        20
# 2761                        Plot area 342(285.96 sq.m.)       16        16
# 2814                        Plot area 316(264.22 sq.m.)       16        20
# 2960  Plot area 1935(179.77 sq.m.)Built Up area: 700...       12        12
# 2971  Plot area 1623(150.78 sq.m.)Built Up area: 162...       19        17
# 3075                  Carpet area: 7250 (6061.92 sq.m.)       10        10
# 3165                        Plot area 200(167.23 sq.m.)       12        12
# 3218                        Plot area 200(167.23 sq.m.)       16        16
# 3274                        Plot area 129(107.86 sq.m.)       21        21
# 3278                        Plot area 305(255.02 sq.m.)       12        12
# 3288  Plot area 201(168.06 sq.m.)Built Up area: 180 ...       12        11
# 3377  Plot area 210(175.59 sq.m.)Built Up area: 205 ...       12        12
# 3465                       Plot area 1300(120.77 sq.m.)       10         7
# 3478                        Plot area 300(250.84 sq.m.)       16        16
# 3495                        Plot area 270(225.75 sq.m.)       16        17
# 3585                        Plot area 502(419.74 sq.m.)       12         4
# 3669  Plot area 2367(219.9 sq.m.)Built Up area: 9000...       12        12
# 3726                        Plot area 500(418.06 sq.m.)       16        16
# 3793                         Plot area 180(150.5 sq.m.)       10         9
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 85        3+       4.0  South-West  Relatively New                  NaN
# 109       3+       3.0       South  Moderately Old                  NaN
# 135       3+       5.0        West    New Property                  NaN
# 138       3+       4.0  North-East  Relatively New                  NaN
# 146       3+       5.0        West    New Property                  NaN
# 237        3       2.0       North    Old Property                  NaN
# 262        3       3.0        East    Old Property                  NaN
# 275       3+       NaN        East    New Property                  NaN
# 460       3+       4.0        East  Relatively New                  NaN
# 467       3+       4.0  South-East  Relatively New                  NaN
# 517       3+       4.0       North  Relatively New                  NaN
# 519       3+       4.0         NaN    New Property                  NaN
# 532       3+       4.0  South-East  Relatively New                  NaN
# 600       3+       4.0  North-West    New Property                  NaN
# 612       3+       4.0  North-West    New Property                  NaN
# 730       3+       3.0        East  Relatively New                  NaN
# 739       3+       4.0        East    New Property                  NaN
# 803        3       1.0         NaN    Old Property                  NaN
# 830       3+       6.0       North    New Property                  NaN
# 834       3+       NaN        West  Moderately Old                  NaN
# 844       3+       4.0         NaN    Old Property                  NaN
# 913       3+       4.0  North-East    New Property                  NaN
# 1017      3+       4.0       North    New Property                  NaN
# 1056      3+       4.0  North-West  Relatively New                  NaN
# 1090      3+       4.0  North-East    New Property                  NaN
# 1136      3+       4.0       North    New Property                  NaN
# 1194      3+       4.0        West    New Property                  NaN
# 1227      3+       4.0  North-East  Relatively New                  NaN
# 1256      3+       4.0  North-East    New Property                  NaN
# 1273      3+       3.0         NaN    New Property                  NaN
# 1428      3+       4.0        West  Relatively New                  NaN
# 1559      3+       1.0       North       Undefined                  NaN
# 1567      3+       6.0        West  Relatively New                  NaN
# 1609      3+       4.0  North-East    New Property                  NaN
# 1721      3+       5.0        West    New Property                  NaN
# 1733      3+       4.0         NaN  Relatively New                  NaN
# 1754       2       4.0        West    New Property                  NaN
# 1845       2       1.0        East       Undefined                  NaN
# 1861      3+       4.0        East    New Property                  NaN
# 2055      3+       3.0       North  Moderately Old                  NaN
# 2272       0       1.0         NaN    New Property                  NaN
# 2303      3+       5.0  North-West  Relatively New                  NaN
# 2316      3+       3.0         NaN    Old Property                  NaN
# 2329       2       3.0  South-East    Old Property                  NaN
# 2335       1       3.0        East  Relatively New                  NaN
# 2340      3+       3.0         NaN    Old Property                  NaN
# 2452      3+       4.0  North-East  Moderately Old                  NaN
# 2476      3+       4.0       North    New Property                  NaN
# 2523      3+       3.0        West  Moderately Old                  NaN
# 2582      3+       3.0       North  Relatively New                  NaN
# 2592      3+       5.0  North-West  Relatively New                  NaN
# 2600       3       4.0         NaN    Old Property                  NaN
# 2682      3+       4.0  North-East    New Property                  NaN
# 2727      3+       4.0        East  Relatively New                  NaN
# 2761      3+       4.0         NaN    New Property                  NaN
# 2814      3+       4.0        East    New Property                  NaN
# 2960      3+       4.0  North-East    New Property                  NaN
# 2971       3       4.0  North-West  Relatively New                  NaN
# 3075      3+       1.0         NaN       Undefined                  NaN
# 3165      3+       4.0       North  Relatively New                  NaN
# 3218      3+       4.0       South  Relatively New                  NaN
# 3274      3+       5.0       North  Relatively New                  NaN
# 3278      3+       4.0        West  Relatively New                  NaN
# 3288      3+       4.0        West  Moderately Old                  NaN
# 3377      3+       4.0        East    New Property                  NaN
# 3465       3       4.0        East  Moderately Old                  NaN
# 3478      3+       4.0  North-West  Relatively New                  NaN
# 3495      3+       4.0       South  Relatively New                  NaN
# 3585      3+       3.0       North    Old Property                  NaN
# 3669       3       4.0  North-West    New Property                  NaN
# 3726      3+       4.0         NaN    New Property                  NaN
# 3793      3+       4.0       North  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 85           1440.0          NaN           0             1           0
# 109           100.0          NaN           1             1           0
# 135           549.0          NaN           0             1           0
# 138           300.0        270.0           0             1           0
# 146           558.0          NaN           0             0           0
# 237          2700.0          NaN           1             1           0
# 262          3159.0          NaN           0             0           0
# 275          1845.0          NaN           0             1           0
# 460           160.0        150.0           0             1           1
# 467          7000.0          NaN           0             0           0
# 517           250.0          NaN           1             1           0
# 519          2367.0          NaN           0             0           1
# 532          2700.0          NaN           1             1           0
# 600           270.0          NaN           1             1           0
# 612           400.0        350.0           1             1           1
# 730          3240.0          NaN           1             1           0
# 739          1935.0          NaN           1             1           1
# 803          2250.0          NaN           1             1           0
# 830          3200.0          NaN           0             1           0
# 834           232.0          NaN           1             1           0
# 844           900.0          NaN           0             0           0
# 913           260.0        245.0           1             1           0
# 1017         1467.0          NaN           0             0           0
# 1056         2367.0          NaN           1             0           0
# 1090          262.0        260.0           0             1           0
# 1136         1600.0          NaN           0             0           0
# 1194          325.0        300.0           1             1           1
# 1227         1503.0          NaN           0             0           0
# 1256         2700.0          NaN           1             1           1
# 1273         1065.0          NaN           0             0           0
# 1428         2736.0          NaN           1             1           0
# 1559          347.0        215.0           0             0           0
# 1567          540.0          NaN           0             0           0
# 1609         2700.0          NaN           0             1           0
# 1721         3000.0          NaN           0             0           0
# 1733         8286.0          NaN           1             1           0
# 1754         2700.0          NaN           0             1           0
# 1845            NaN        360.0           0             0           0
# 1861         1728.0          NaN           0             1           1
# 2055         2088.0          NaN           1             1           0
# 2272         2250.0          NaN           0             0           0
# 2303         7500.0          NaN           1             0           1
# 2316         3500.0          NaN           0             0           0
# 2329          115.0          NaN           0             0           0
# 2335         1170.0          NaN           1             1           0
# 2340         1431.0          NaN           0             0           0
# 2452         7500.0       6000.0           1             1           0
# 2476         1800.0          NaN           0             1           0
# 2523         2115.0          NaN           0             0           0
# 2582         5018.0          NaN           0             0           0
# 2592          145.0          NaN           0             0           0
# 2600           55.0          NaN           0             0           0
# 2682         4518.0          NaN           1             1           1
# 2727         1152.0          NaN           0             1           0
# 2761         3078.0          NaN           1             1           1
# 2814         2844.0          NaN           1             1           1
# 2960         7000.0          NaN           0             1           0
# 2971         1622.0          NaN           1             1           1
# 3075            NaN       7250.0           0             0           0
# 3165         1800.0          NaN           0             1           0
# 3218         1800.0          NaN           0             0           0
# 3274         1161.0          NaN           0             1           0
# 3278         2745.0          NaN           0             1           0
# 3288          180.0        150.0           0             0           0
# 3377          205.0        200.0           0             1           0
# 3465         1300.0          NaN           0             0           0
# 3478         2700.0          NaN           1             1           0
# 3495         2430.0          NaN           1             1           0
# 3585         4518.0          NaN           0             1           1
# 3669         9000.0       6000.0           0             1           0
# 3726          500.0          NaN           0             1           0
# 3793         1620.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 85             0       0                0            70
# 109            1       1                1             0
# 135            0       0                1            20
# 138            1       0                2            72
# 146            0       1                0            20
# 237            1       0                1             8
# 262            1       0                2            64
# 275            0       1                2            40
# 460            0       0                2            56
# 467            1       0                0            38
# 517            0       0                2           114
# 519            0       0                2            57
# 532            1       0                2            49
# 600            1       1                1            41
# 612            1       0                0            72
# 730            1       0                0           122
# 739            1       0                2            72
# 803            1       1                2             0
# 830            0       0                0            50
# 834            1       1                2            49
# 844            0       0                1             0
# 913            1       1                0           144
# 1017           1       0                0            91
# 1056           1       0                2            32
# 1090           1       1                0            49
# 1136           0       0                2            99
# 1194           1       0                0            72
# 1227           0       1                0            57
# 1256           1       0                2           144
# 1273           0       0                1             0
# 1428           1       0                2            49
# 1559           0       0                1             0
# 1567           0       0                0            15
# 1609           1       0                2            49
# 1721           0       1                0            28
# 1733           1       0                0           107
# 1754           1       0                2            49
# 1845           0       0                1             0
# 1861           0       0                2            73
# 2055           1       1                2            49
# 2272           0       0                1             0
# 2303           0       0                1            68
# 2316           0       0                1             0
# 2329           0       1                1             7
# 2335           1       1                2           106
# 2340           0       0                1             0
# 2452           0       0                2            70
# 2476           0       0                2           105
# 2523           0       1                1            49
# 2582           0       1                0            29
# 2592           0       0                0             7
# 2600           0       0                1            15
# 2682           1       0                2           153
# 2727           0       0                0            22
# 2761           1       0                2             0
# 2814           1       0                2           153
# 2960           1       0                2            43
# 2971           1       0                1            74
# 3075           0       0                1             0
# 3165           1       0                2            42
# 3218           0       0                2            20
# 3274           0       0                0            49
# 3278           0       0                2            21
# 3288           1       0                0            44
# 3377           1       0                2            40
# 3465           0       0                1             0
# 3478           1       1                1            41
# 3495           1       1                0           137
# 3585           0       0                1            32
# 3669           0       0                2            71
# 3726           0       0                2            31
# 3793           0       0                2            36

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers

df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 34           house           dlf the arbour   sector 63   8.50
# 170          house          godrej meridien  sector 106   5.60
# 491          house              spaze privy   sector 72   3.10
# 742          house        suncity avenue 76   sector 76   0.75
# 1095         house              greenopolis   sector 89   0.70
# 1126         house      satya the hermitage  sector 103   3.15
# 1442         house   vatika the seven lamps   sector 82   1.60
# 2315         house               ninex city   sector 76   1.75
# 2717         house              spaze privy   sector 72   3.09
# 2719         house           ats tourmaline  sector 109   1.87
# 3223         house         suncity township   sector 54   2.00
# 3224         house  indiabulls centrum park  sector 103   3.25
# 3394         house              independent   sector 92   1.80
# 3691         house      ireo victory valley   sector 67   8.00
#
#       price_per_sqft    area  \
# 34           21519.0  3950.0
# 170          14000.0  4000.0
# 491           8486.0  3653.0
# 742          10067.0   745.0
# 1095          5397.0  1297.0
# 1126          6702.0  4700.0
# 1442          6597.0  2425.0
# 2315          6250.0  2800.0
# 2717          6981.0  4426.0
# 2719          8697.0  2150.0
# 3223         30968.0   646.0
# 3224          8125.0  4000.0
# 3394          7627.0  2360.0
# 3691         22222.0  3600.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 34                   Built Up area: 3950 (366.97 sq.m.)        4         4
# 170                        Plot area 4000(371.61 sq.m.)        5         4
# 491                        Plot area 3653(339.37 sq.m.)        5         5
# 742   Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 1095                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1126                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 1442                       Plot area 2425(225.29 sq.m.)        4         4
# 2315                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 2717  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 2719                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 3223  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 3224                       Plot area 4000(371.61 sq.m.)        4         3
# 3394                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 3691                        Plot area 400(334.45 sq.m.)        6         7
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 34        3+      27.0         NaN           Undefined                  NaN
# 170       3+      33.0  North-East        New Property                  NaN
# 491       3+      21.0         NaN      Relatively New                  NaN
# 742        2      11.0  North-East        New Property                  NaN
# 1095       2      14.0  North-East           Undefined                  NaN
# 1126       0      12.0        East           Undefined                  NaN
# 1442      3+      16.0       North      Moderately Old                  NaN
# 2315       0      14.0         NaN           Undefined                  NaN
# 2717      3+      14.0        East      Relatively New                  NaN
# 2719       0      12.0         NaN           Undefined                  NaN
# 3223       3      11.0       North      Relatively New                  NaN
# 3224      3+      20.0         NaN  Under Construction                  NaN
# 3394       0      13.0         NaN           Undefined                  NaN
# 3691      3+      51.0  North-East      Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 34           3950.0          NaN           0             0           0
# 170          4000.0          NaN           1             1           1
# 491          3653.0          NaN           0             0           0
# 742           745.0          NaN           0             0           0
# 1095         1297.0          NaN           0             0           0
# 1126         4700.0          NaN           0             0           0
# 1442         2425.0          NaN           0             1           0
# 2315            NaN       2800.0           0             0           0
# 2717         3653.0       2922.0           0             1           0
# 2719         2150.0          NaN           0             0           0
# 3223           60.0         59.0           0             1           0
# 3224         4000.0          NaN           0             0           0
# 3394         2360.0          NaN           0             0           0
# 3691         3600.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 34             0       0                1            61
# 170            1       0                1           151
# 491            0       0                1             0
# 742            0       0                1            40
# 1095           0       0                1             0
# 1126           0       0                1            61
# 1442           0       0                1            94
# 2315           0       0                1             0
# 2717           0       0                2            33
# 2719           0       0                1             0
# 3223           0       0                0             7
# 3224           0       0                1            51
# 3394           0       0                1             0
# 3691           1       0                2            49

# %% [markdown]
# # conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat        bestech altura  sector 79   1.85          8604.0
# 1          flat            rof ananda  sector 95   0.46          6318.0
# 2         house           independent   sector 9   0.22          7407.0
# 3          flat  umang monsoon breeze  sector 78   0.95          5491.0
# 4          flat         tata primanti  sector 72   4.00         13769.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0  2150.0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1   728.0          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2   297.0           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3  1730.0      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  2905.0  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0      11.0       North    New Property               2150.0            NaN
# 1      11.0  North-West    New Property                  NaN            NaN
# 2       1.0         NaN       Undefined                  NaN            NaN
# 3       9.0        East  Relatively New                  NaN         1730.0
# 4       7.0  South-East  Moderately Old               2905.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0          NaN           0             1           0           0       0
# 1        728.0           1             0           0           0       0
# 2         33.0           0             0           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             1           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            49
# 1                1            82
# 2                1             0
# 3                2            65
# 4                1            38

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat        bestech altura  sector 79   1.85          8604.0
# 1          flat            rof ananda  sector 95   0.46          6318.0
# 2         house           independent   sector 9   0.22          7407.0
# 3          flat  umang monsoon breeze  sector 78   0.95          5491.0
# 4          flat         tata primanti  sector 72   4.00         13769.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0  2150.0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1   728.0          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2   297.0           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3  1730.0      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  2905.0  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0      11.0       North    New Property               2150.0            NaN
# 1      11.0  North-West    New Property                  NaN            NaN
# 2       1.0         NaN       Undefined                  NaN            NaN
# 3       9.0        East  Relatively New                  NaN         1730.0
# 4       7.0  South-East  Moderately Old               2905.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0          NaN           0             1           0           0       0
# 1        728.0           1             0           0           0       0
# 2         33.0           0             0           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             1           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            49
# 1                1            82
# 2                1             0
# 3                2            65
# 4                1            38

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type               society     sector  price  price_per_sqft  \
# 0          flat        bestech altura  sector 79   1.85          8604.0
# 1          flat            rof ananda  sector 95   0.46          6318.0
# 2         house           independent   sector 9   0.22          7407.0
# 3          flat  umang monsoon breeze  sector 78   0.95          5491.0
# 4          flat         tata primanti  sector 72   4.00         13769.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0  2150.0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1   728.0          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2   297.0           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3  1730.0      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  2905.0  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0      11.0       North    New Property               2150.0            NaN
# 1      11.0  North-West    New Property                  NaN            NaN
# 2       1.0         NaN       Undefined                  NaN            NaN
# 3       9.0        East  Relatively New                  NaN         1730.0
# 4       7.0  South-East  Moderately Old               2905.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0          NaN           0             1           0           0       0
# 1        728.0           1             0           0           0       0
# 2         33.0           0             0           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             1           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            49
# 1                1            82
# 2                1             0
# 3                2            65
# 4                1            38

# %% [markdown]
# ### price

# %%
### price
plt.figure(figsize=(12,8))
# Issue: The scatterplot() function is receiving two positional arguments, but it expects only one.
# Explanation: The first argument is expected to be the data, and the second should be the hue.
# Fix: Separate the data into x and y arguments.
sns.scatterplot(x=df[df['area']<10000]['area'], y=df[df['area']<10000]['price'], hue=df[df['area']<10000]['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'], y=df[df['area']<10000]['price'], hue=df[df['area']<10000]['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df[df['area']<10000]['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = df['furnishing_type'],  y = df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'], y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
numeric_df = df.select_dtypes(include=['number'])
df = numeric_df.corr()

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# bathroom               0.808907
# bedRoom                0.776311
# servant room           0.571308
# price_per_sqft         0.506877
# super_built_up_area    0.462204
# built_up_area          0.434901
# pooja room             0.384926
# store room             0.306149
# study room             0.177303
# carpet_area           -0.012110
# furnishing_type       -0.074779
# area                  -0.078596
# luxury_score          -0.093103
# others                -0.270504
# floorNum              -0.390254
# Name: price, dtype: float64

# %%
df.head()
# Out:
#                    price  price_per_sqft      area   bedRoom  bathroom  \
# price           1.000000        0.391242  0.034726  0.522940  0.589835
# price_per_sqft  0.391242        1.000000 -0.027287  0.314227  0.294874
# area            0.034726       -0.027287  1.000000  0.016870  0.018806
# bedRoom         0.522940        0.314227  0.016870  1.000000  0.908884
# bathroom        0.589835        0.294874  0.018806  0.908884  1.000000
#
#                 floorNum  super_built_up_area  built_up_area  carpet_area  \
# price          -0.094199             0.769236       0.551649    -0.011344
# price_per_sqft -0.112623             0.281203      -0.079228    -0.036319
# area           -0.022733             0.968783       0.174319     0.992773
# bedRoom        -0.131104             0.734980       0.225665    -0.019114
# bathroom       -0.068722             0.740385       0.301037    -0.016240
#
#                 study room  servant room  store room  pooja room    others  \
# price             0.258630      0.400952    0.309139    0.341516 -0.003497
# price_per_sqft    0.095878      0.103080    0.087116    0.122250  0.010576
# area              0.028640      0.010890    0.007024    0.010037  0.034229
# bedRoom           0.137322      0.278657    0.181227    0.272101  0.073332
# bathroom          0.161984      0.411667    0.196453    0.286469  0.066035
#
#                 furnishing_type  luxury_score
# price                  0.118454      0.094860
# price_per_sqft         0.043018     -0.044341
# area                  -0.000378     -0.002970
# bedRoom                0.050056     -0.020211
# bathroom               0.083273      0.096061

# %%
sns.pairplot(df)

# %%
# import libraries


import numpy as np
import pandas as pd

# %%
# Taking both the file to merge

flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
# Merge the file

df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                 property_name property_type  \
# 0             3 BHK Flat in Sector 79 Gurgaon          flat
# 1             2 BHK Flat in Sector 95 Gurgaon          flat
# 2  2 Bedroom House for sale in Devilal Colony         house
# 3             3 BHK Flat in Sector 78 Gurgaon          flat
# 4             4 BHK Flat in Sector 72 Gurgaon          flat
#
#                 society  price  price_per_sqft    area  \
# 0        bestech altura   1.85          8604.0  2150.0
# 1            rof ananda   0.46          6318.0   728.0
# 2           independent   0.22          7407.0   297.0
# 3  umang monsoon breeze   0.95          5491.0  1730.0
# 4         tata primanti   4.00         13769.0  2905.0
#
#                              areaWithType  bedRoom  bathroom balcony  \
# 0  Super Built up area 2150(199.74 sq.m.)        3         4      3+
# 1          Carpet area: 728 (67.63 sq.m.)        2         2       2
# 2           Carpet area: 33 (27.59 sq.m.)        2         2       2
# 3      Built Up area: 1730 (160.72 sq.m.)        3         3       2
# 4  Super Built up area 2905(269.88 sq.m.)        4         5       2
#
#   additionalRoom                                            address  floorNum  \
# 0   servant room                Sector 79 Gurgaon, Gurgaon, Haryana      11.0
# 1     study room                Sector 95 Gurgaon, Gurgaon, Haryana      11.0
# 2  not available  Devilal Colony, Sector 9, Basai Road, Devilal ...       1.0
# 3  not available                Sector 78 Gurgaon, Gurgaon, Haryana       9.0
# 4   servant room                Sector 72 Gurgaon, Gurgaon, Haryana       7.0
#
#        facing     agePossession  \
# 0       North   0 to 1 Year Old
# 1  North-West   0 to 1 Year Old
# 2         NaN         undefined
# 3        East   1 to 5 Year Old
# 4  South-East  5 to 10 Year Old
#
#                                      nearbyLocations  \
# 0  ['Sapphire 83 Mall', 'NH -8', 'Golf Course Ext...
# 1  ['Metro', 'Dwarka Expressway', 'Rajeev Chowk',...
# 2                                                NaN
# 3  ['Proposed Metro Station', 'Mahapal Shing', 'N...
# 4  ['Sector 55-56 Metro Station', 'Omaxe City Cen...
#
#                                          description  \
# 0  This lovely 3 bhk apartment/flat in sector 79 ...
# 1  2 bhk+study apartment, garden facing balconies...
# 2  Best in class property available at devilal co...
# 3  Good construction and well maintained society....
# 4  4 bedroom, 2905 sq.Ft. Is available for sale i...
#
#                                       furnishDetails  \
# 0  ['5 AC', '1 Chimney', '1 Modular Kitchen', 'No...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Fan', '1 Exhaust Fan', '2 Geyser', '7 Ligh...
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2                                                NaN
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Safety4.5 out of 5', 'Lifestyle4.5 out of 5'...
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
# Export the merged file

df.to_csv('gurgaon_properties.csv',index=False)
